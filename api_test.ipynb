# %%
# imports
import requests
import os
from pprint import pprint
from dotenv import load_dotenv
from pathlib import Path

# Pfade
ROOT = Path().resolve()
path_to_token = ROOT / 'sql' /'data' / 'secret' / 'token.env'

# URLs
books_url = 'https://localhost:58723/bookstore/books/'
logs_url = 'https://localhost:58723/bookstore/logs/'

# %%
# Alle Bücher abrufen funktioniert nicht, da das SSL Zertifikat nicht echt ist.
response = requests.get(books_url)
print('Status Code: ', response.status_code)
pprint(response.json())
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:790, in HTTPSConnection.connect(self)
#     788 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 790 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     791     sock=sock,
#     792     cert_reqs=self.cert_reqs,
#     793     ssl_version=self.ssl_version,
#     794     ssl_minimum_version=self.ssl_minimum_version,
#     795     ssl_maximum_version=self.ssl_maximum_version,
#     796     ca_certs=self.ca_certs,
#     797     ca_cert_dir=self.ca_cert_dir,
#     798     ca_cert_data=self.ca_cert_data,
#     799     cert_file=self.cert_file,
#     800     key_file=self.key_file,
#     801     key_password=self.key_password,
#     802     server_hostname=server_hostname_rm_dot,
#     803     ssl_context=self.ssl_context,
#     804     tls_in_tls=tls_in_tls,
#     805     assert_hostname=self.assert_hostname,
#     806     assert_fingerprint=self.assert_fingerprint,
#     807 )
#     808 self.sock = sock_and_verified.socket
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:969, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     967         server_hostname = normalized
# --> 969 ssl_sock = ssl_wrap_socket(
#     970     sock=sock,
#     971     keyfile=key_file,
#     972     certfile=cert_file,
#     973     key_password=key_password,
#     974     ca_certs=ca_certs,
#     975     ca_cert_dir=ca_cert_dir,
#     976     ca_cert_data=ca_cert_data,
#     977     server_hostname=server_hostname,
#     978     ssl_context=context,
#     979     tls_in_tls=tls_in_tls,
#     980 )
#     982 try:
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\ssl_.py:480, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     478 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 480 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     481 return ssl_sock
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\ssl_.py:524, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     522     return SSLTransport(sock, ssl_context, server_hostname)
# --> 524 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1076, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1075                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1076             self.do_handshake()
#    1077 except:
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1372, in SSLSocket.do_handshake(self, block)
#    1371         self.settimeout(None)
# -> 1372     self._sslobj.do_handshake()
#    1373 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1028)
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# SSLError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1028)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='localhost', port=58723): Max retries exceeded with url: /bookstore/books/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1028)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Alle Bücher abrufen funktioniert nicht, da das SSL Zertifikat nicht echt ist.
# ----> 2 response = requests.get(books_url)
#       3 print('Status Code: ', response.status_code)
#       4 pprint(response.json())
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:675, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     671         raise ProxyError(e, request=request)
#     673     if isinstance(e.reason, _SSLError):
#     674         # This branch is for urllib3 v1.22 and later.
# --> 675         raise SSLError(e, request=request)
#     677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#
# SSLError: HTTPSConnectionPool(host='localhost', port=58723): Max retries exceeded with url: /bookstore/books/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate (_ssl.c:1028)')))

# %%
# verify = false, weil das ssl Zertifikat selbst erstellt ist
response = requests.get(books_url, verify = False)
print('Status Code: ', response.status_code)
pprint(response.json())
# Out:
# Status Code:  200
# [{'author': 'Anna Meier',
#   'id': 1,
#   'in_stock': 0,
#   'pages': 312,
#   'price': 19.99,
#   'publication_year': 2020,
#   'publisher': 'Nordlicht Verlag',
#   'title': 'Der stille Fluss'},
#  {'author': 'Lukas Brandt',
#   'id': 2,
#   'in_stock': 26,
#   'pages': 280,
#   'price': 17.5,
#   'publication_year': 2018,
#   'publisher': 'Südwind Verlag',
#   'title': 'Schatten im Licht'},
#  {'author': 'Clara König',
#   'id': 3,
#   'in_stock': 11,
#   'pages': 415,
#   'price': 29.9,
#   'publication_year': 2021,
#   'publisher': 'TechBooks',
#   'title': 'Der Programmierer'},
#  {'author': 'Paul Richter',
#   'id': 4,
#   'in_stock': 0,
#   'pages': 198,
#   'price': 12.0,
#   'publication_year': 2015,
#   'publisher': 'Grünwald Verlag',
#   'title': 'Geschichten aus dem Wald'},
#  {'author': 'Mia Fischer',
#   'id': 5,
#   'in_stock': 36,
#   'pages': 365,
#   'price': 22.99,
#   'publication_year': 2019,
#   'publisher': 'Sturm & Drang',
#   'title': 'Im Auge des Orkans'},
#  {'author': 'Jonas Neumann',
#   'id': 6,
#   'in_stock': 52,
#   'pages': 344,
#   'price': 31.5,
#   'publication_year': 2022,
#   'publisher': 'Future Press',
#   'title': 'Digitale Welten'},
#  {'author': 'Sarah Müller',
#   'id': 7,
#   'in_stock': 0,
#   'pages': 190,
#   'price': 15.8,
#   'publication_year': 2017,
#   'publisher': 'Café-Verlag',
#   'title': 'Kaffee & Gedanken'},
#  {'author': 'Dr. Felix Weber',
#   'id': 8,
#   'in_stock': 13,
#   'pages': 512,
#   'price': 34.9,
#   'publication_year': 2020,
#   'publisher': 'Wissen Kompakt',
#   'title': 'Mathematik für Neugierige'},
#  {'author': 'Nora Schwarz',
#   'id': 9,
#   'in_stock': 7,
#   'pages': 278,
#   'price': 16.5,
#   'publication_year': 2016,
#   'publisher': 'Dunkellicht Verlag',
#   'title': 'Die Farbe der Nacht'},
#  {'author': 'Tom Berger',
#   'id': 10,
#   'in_stock': 3,
#   'pages': 402,
#   'price': 25.0,
#   'publication_year': 2021,
#   'publisher': 'Galaxy Books',
#   'title': 'Reise zum Mars'},
#  {'author': 'Laura Sommer',
#   'id': 11,
#   'in_stock': 60,
#   'pages': 330,
#   'price': 14.99,
#   'publication_year': 2014,
#   'publisher': 'Romance Edition',
#   'title': 'Herz über Kopf'},
#  {'author': 'Manuel Frei',
#   'id': 12,
#   'in_stock': 9,
#   'pages': 222,
#   'price': 13.8,
#   'publication_year': 2013,
#   'publisher': 'Bergblick Verlag',
#   'title': 'Wolkenbruch'},
#  {'author': 'Elisabeth Frank',
#   'id': 13,
#   'in_stock': 0,
#   'pages': 388,
#   'price': 27.99,
#   'publication_year': 2022,
#   'publisher': 'Wissenschaft Aktuell',
#   'title': 'Die letzte Formel'},
#  {'author': 'Bäckermeister Huber',
#   'id': 14,
#   'in_stock': 21,
#   'pages': 150,
#   'price': 11.2,
#   'publication_year': 2010,
#   'publisher': 'Haus & Hof',
#   'title': 'Vom Korn zum Brot'},
#  {'author': 'Linda Roth',
#   'id': 15,
#   'in_stock': 33,
#   'pages': 290,
#   'price': 24.9,
#   'publication_year': 2018,
#   'publisher': 'Bildschön Verlag',
#   'title': 'Fotografie heute'},
#  {'author': 'Akiko Tanaka',
#   'id': 16,
#   'in_stock': 0,
#   'pages': 310,
#   'price': 22.5,
#   'publication_year': 2019,
#   'publisher': 'Asien Kultur',
#   'title': 'Tee & Tradition'},
#  {'author': 'Max Hartmann',
#   'id': 17,
#   'in_stock': 2,
#   'pages': 370,
#   'price': 28.8,
#   'publication_year': 2021,
#   'publisher': 'CodePress',
#   'title': 'Code & Kaffee'},
#  {'author': 'Tanja Reichel',
#   'id': 18,
#   'in_stock': 19,
#   'pages': 280,
#   'price': 18.5,
#   'publication_year': 2016,
#   'publisher': 'PsychoVerlag',
#   'title': 'Der Glasmensch'},
#  {'author': 'Nils Keller',
#   'id': 19,
#   'in_stock': 38,
#   'pages': 405,
#   'price': 31.2,
#   'publication_year': 2020,
#   'publisher': 'Öko Verlag',
#   'title': 'Energie der Zukunft'},
#  {'author': 'Yvonne Stern',
#   'id': 20,
#   'in_stock': 15,
#   'pages': 450,
#   'price': 35.0,
#   'publication_year': 2023,
#   'publisher': 'Cosmos Books',
#   'title': 'Sterne und Staub'},
#  {'author': 'Gregor Busch',
#   'id': 21,
#   'in_stock': 47,
#   'pages': 250,
#   'price': 14.7,
#   'publication_year': 2015,
#   'publisher': 'Natur Pur',
#   'title': 'Wald der Geheimnisse'},
#  {'author': 'Nico Bauer',
#   'id': 22,
#   'in_stock': 1,
#   'pages': 320,
#   'price': 29.9,
#   'publication_year': 2021,
#   'publisher': 'CodeCraft',
#   'title': 'Python Basics'},
#  {'author': 'Franziska Adler',
#   'id': 23,
#   'in_stock': 5,
#   'pages': 275,
#   'price': 19.9,
#   'publication_year': 2018,
#   'publisher': 'Historica',
#   'title': 'Das verlorene Manuskript'},
#  {'author': 'Jan Krüger',
#   'id': 24,
#   'in_stock': 44,
#   'pages': 210,
#   'price': 16.8,
#   'publication_year': 2019,
#   'publisher': 'Balance Verlag',
#   'title': 'Digital Detox'},
#  {'author': 'Claire Dubois',
#   'id': 25,
#   'in_stock': 22,
#   'pages': 350,
#   'price': 20.0,
#   'publication_year': 2020,
#   'publisher': 'Sprachenwelt',
#   'title': 'Einfach Französisch'},
#  {'author': 'Michael Schulz',
#   'id': 26,
#   'in_stock': 14,
#   'pages': 410,
#   'price': 32.0,
#   'publication_year': 2022,
#   'publisher': 'DevBooks',
#   'title': 'Java für Einsteiger'},
#  {'author': 'Julia Winter',
#   'id': 27,
#   'in_stock': 41,
#   'pages': 265,
#   'price': 21.9,
#   'publication_year': 2017,
#   'publisher': 'Autoren Verlag',
#   'title': 'Kreatives Schreiben'},
#  {'author': 'Sven Römer',
#   'id': 28,
#   'in_stock': 6,
#   'pages': 198,
#   'price': 14.5,
#   'publication_year': 2016,
#   'publisher': 'Haushalt & Technik',
#   'title': 'Die Kaffeemaschine'},
#  {'author': 'Elena Kraus',
#   'id': 29,
#   'in_stock': 17,
#   'pages': 390,
#   'price': 33.3,
#   'publication_year': 2021,
#   'publisher': 'AI Press',
#   'title': 'Der Algorithmus'},
#  {'author': 'Ben Fischer',
#   'id': 30,
#   'in_stock': 58,
#   'pages': 310,
#   'price': 23.9,
#   'publication_year': 2023,
#   'publisher': 'KrimiKunst',
#   'title': 'Mitternachtskrimi'}]
# c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# Versuch, ein Buch zu erstellen
book_data = {
    "title": "Beispiel Buch",
    "author": "Max Mustermann",
    "publication_year": 2023,
    "publisher": "Test Verlag",
    "pages": 300,
    "price": 19.99,
    "in_stock": True
}

response = requests.post(books_url, json = book_data, verify = False)

print('Status Code:', response.status_code)
print(response.json())
# Out:
# Status Code: 403
# {'detail': 'Not authenticated'}
# c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# Token laden
load_dotenv(path_to_token)
token = os.getenv('API_TOKEN')
# Out:
# F:\Data Science\Projects\prepared_Praxisprojekt_04A_Buchhandlung_mit_Cafe\sql\data\secret\token.env
# f29a7e2c9c814f35a6bcd1a3e47d8f4e

# %%
# Lesen kann man ohne Schlüssel (Token); Schreiben, Löschen oder Editieren nur mit Schlüssel
book_data = {
    "title": "Beispiel Buch",
    "author": "Max Mustermann",
    "publication_year": 2023,
    "publisher": "Test Verlag",
    "pages": 300,
    "price": 19.99,
    "in_stock": True
}

# bearer wie Träger, hier gibt man den Schlüssel (Token) mit
headers = {
    'Authorization': f'Bearer {token}' }

response = requests.post(books_url, headers = headers, json = book_data, verify = False)

print("Status:", response.status_code)

result = response.json()
pprint(result)
# Out:
# Status: 201
# {'author': 'Max Mustermann',
#  'id': 31,
#  'in_stock': 1,
#  'pages': 300,
#  'price': 19.99,
#  'publication_year': 2023,
#  'publisher': 'Test Verlag',
#  'title': 'Beispiel Buch'}
# c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# Logs abrufen nur mit Schlüssel
headers = {
    'Authorization': f'Bearer {token}' }

response = requests.get(logs_url, headers = headers, verify = False)

print("Status:", response.status_code)

result = response.json()
pprint(result)
# Out:
# Status: 200
# [{'id': 1,
#   'item_id': 1,
#   'new_data': {'author': 'Anna Meier',
#                'id': 1,
#                'in_stock': 0,
#                'pages': 312,
#                'price': 19.99,
#                'publication_year': 2020,
#                'publisher': 'Nordlicht Verlag',
#                'title': 'Der stille Fluss'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 2,
#   'item_id': 2,
#   'new_data': {'author': 'Lukas Brandt',
#                'id': 2,
#                'in_stock': 26,
#                'pages': 280,
#                'price': 17.5,
#                'publication_year': 2018,
#                'publisher': 'Südwind Verlag',
#                'title': 'Schatten im Licht'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 3,
#   'item_id': 3,
#   'new_data': {'author': 'Clara König',
#                'id': 3,
#                'in_stock': 11,
#                'pages': 415,
#                'price': 29.9,
#                'publication_year': 2021,
#                'publisher': 'TechBooks',
#                'title': 'Der Programmierer'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 4,
#   'item_id': 4,
#   'new_data': {'author': 'Paul Richter',
#                'id': 4,
#                'in_stock': 0,
#                'pages': 198,
#                'price': 12.0,
#                'publication_year': 2015,
#                'publisher': 'Grünwald Verlag',
#                'title': 'Geschichten aus dem Wald'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 5,
#   'item_id': 5,
#   'new_data': {'author': 'Mia Fischer',
#                'id': 5,
#                'in_stock': 36,
#                'pages': 365,
#                'price': 22.99,
#                'publication_year': 2019,
#                'publisher': 'Sturm & Drang',
#                'title': 'Im Auge des Orkans'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 6,
#   'item_id': 6,
#   'new_data': {'author': 'Jonas Neumann',
#                'id': 6,
#                'in_stock': 52,
#                'pages': 344,
#                'price': 31.5,
#                'publication_year': 2022,
#                'publisher': 'Future Press',
#                'title': 'Digitale Welten'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 7,
#   'item_id': 7,
#   'new_data': {'author': 'Sarah Müller',
#                'id': 7,
#                'in_stock': 0,
#                'pages': 190,
#                'price': 15.8,
#                'publication_year': 2017,
#                'publisher': 'Café-Verlag',
#                'title': 'Kaffee & Gedanken'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 8,
#   'item_id': 8,
#   'new_data': {'author': 'Dr. Felix Weber',
#                'id': 8,
#                'in_stock': 13,
#                'pages': 512,
#                'price': 34.9,
#                'publication_year': 2020,
#                'publisher': 'Wissen Kompakt',
#                'title': 'Mathematik für Neugierige'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 9,
#   'item_id': 9,
#   'new_data': {'author': 'Nora Schwarz',
#                'id': 9,
#                'in_stock': 7,
#                'pages': 278,
#                'price': 16.5,
#                'publication_year': 2016,
#                'publisher': 'Dunkellicht Verlag',
#                'title': 'Die Farbe der Nacht'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 10,
#   'item_id': 10,
#   'new_data': {'author': 'Tom Berger',
#                'id': 10,
#                'in_stock': 3,
#                'pages': 402,
#                'price': 25.0,
#                'publication_year': 2021,
#                'publisher': 'Galaxy Books',
#                'title': 'Reise zum Mars'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 11,
#   'item_id': 11,
#   'new_data': {'author': 'Laura Sommer',
#                'id': 11,
#                'in_stock': 60,
#                'pages': 330,
#                'price': 14.99,
#                'publication_year': 2014,
#                'publisher': 'Romance Edition',
#                'title': 'Herz über Kopf'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 12,
#   'item_id': 12,
#   'new_data': {'author': 'Manuel Frei',
#                'id': 12,
#                'in_stock': 9,
#                'pages': 222,
#                'price': 13.8,
#                'publication_year': 2013,
#                'publisher': 'Bergblick Verlag',
#                'title': 'Wolkenbruch'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 13,
#   'item_id': 13,
#   'new_data': {'author': 'Elisabeth Frank',
#                'id': 13,
#                'in_stock': 0,
#                'pages': 388,
#                'price': 27.99,
#                'publication_year': 2022,
#                'publisher': 'Wissenschaft Aktuell',
#                'title': 'Die letzte Formel'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 14,
#   'item_id': 14,
#   'new_data': {'author': 'Bäckermeister Huber',
#                'id': 14,
#                'in_stock': 21,
#                'pages': 150,
#                'price': 11.2,
#                'publication_year': 2010,
#                'publisher': 'Haus & Hof',
#                'title': 'Vom Korn zum Brot'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 15,
#   'item_id': 15,
#   'new_data': {'author': 'Linda Roth',
#                'id': 15,
#                'in_stock': 33,
#                'pages': 290,
#                'price': 24.9,
#                'publication_year': 2018,
#                'publisher': 'Bildschön Verlag',
#                'title': 'Fotografie heute'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 16,
#   'item_id': 16,
#   'new_data': {'author': 'Akiko Tanaka',
#                'id': 16,
#                'in_stock': 0,
#                'pages': 310,
#                'price': 22.5,
#                'publication_year': 2019,
#                'publisher': 'Asien Kultur',
#                'title': 'Tee & Tradition'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 17,
#   'item_id': 17,
#   'new_data': {'author': 'Max Hartmann',
#                'id': 17,
#                'in_stock': 2,
#                'pages': 370,
#                'price': 28.8,
#                'publication_year': 2021,
#                'publisher': 'CodePress',
#                'title': 'Code & Kaffee'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 18,
#   'item_id': 18,
#   'new_data': {'author': 'Tanja Reichel',
#                'id': 18,
#                'in_stock': 19,
#                'pages': 280,
#                'price': 18.5,
#                'publication_year': 2016,
#                'publisher': 'PsychoVerlag',
#                'title': 'Der Glasmensch'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 19,
#   'item_id': 19,
#   'new_data': {'author': 'Nils Keller',
#                'id': 19,
#                'in_stock': 38,
#                'pages': 405,
#                'price': 31.2,
#                'publication_year': 2020,
#                'publisher': 'Öko Verlag',
#                'title': 'Energie der Zukunft'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 20,
#   'item_id': 20,
#   'new_data': {'author': 'Yvonne Stern',
#                'id': 20,
#                'in_stock': 15,
#                'pages': 450,
#                'price': 35.0,
#                'publication_year': 2023,
#                'publisher': 'Cosmos Books',
#                'title': 'Sterne und Staub'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 21,
#   'item_id': 21,
#   'new_data': {'author': 'Gregor Busch',
#                'id': 21,
#                'in_stock': 47,
#                'pages': 250,
#                'price': 14.7,
#                'publication_year': 2015,
#                'publisher': 'Natur Pur',
#                'title': 'Wald der Geheimnisse'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 22,
#   'item_id': 22,
#   'new_data': {'author': 'Nico Bauer',
#                'id': 22,
#                'in_stock': 1,
#                'pages': 320,
#                'price': 29.9,
#                'publication_year': 2021,
#                'publisher': 'CodeCraft',
#                'title': 'Python Basics'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 23,
#   'item_id': 23,
#   'new_data': {'author': 'Franziska Adler',
#                'id': 23,
#                'in_stock': 5,
#                'pages': 275,
#                'price': 19.9,
#                'publication_year': 2018,
#                'publisher': 'Historica',
#                'title': 'Das verlorene Manuskript'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 24,
#   'item_id': 24,
#   'new_data': {'author': 'Jan Krüger',
#                'id': 24,
#                'in_stock': 44,
#                'pages': 210,
#                'price': 16.8,
#                'publication_year': 2019,
#                'publisher': 'Balance Verlag',
#                'title': 'Digital Detox'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 25,
#   'item_id': 25,
#   'new_data': {'author': 'Claire Dubois',
#                'id': 25,
#                'in_stock': 22,
#                'pages': 350,
#                'price': 20.0,
#                'publication_year': 2020,
#                'publisher': 'Sprachenwelt',
#                'title': 'Einfach Französisch'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 26,
#   'item_id': 26,
#   'new_data': {'author': 'Michael Schulz',
#                'id': 26,
#                'in_stock': 14,
#                'pages': 410,
#                'price': 32.0,
#                'publication_year': 2022,
#                'publisher': 'DevBooks',
#                'title': 'Java für Einsteiger'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 27,
#   'item_id': 27,
#   'new_data': {'author': 'Julia Winter',
#                'id': 27,
#                'in_stock': 41,
#                'pages': 265,
#                'price': 21.9,
#                'publication_year': 2017,
#                'publisher': 'Autoren Verlag',
#                'title': 'Kreatives Schreiben'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 28,
#   'item_id': 28,
#   'new_data': {'author': 'Sven Römer',
#                'id': 28,
#                'in_stock': 6,
#                'pages': 198,
#                'price': 14.5,
#                'publication_year': 2016,
#                'publisher': 'Haushalt & Technik',
#                'title': 'Die Kaffeemaschine'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 29,
#   'item_id': 29,
#   'new_data': {'author': 'Elena Kraus',
#                'id': 29,
#                'in_stock': 17,
#                'pages': 390,
#                'price': 33.3,
#                'publication_year': 2021,
#                'publisher': 'AI Press',
#                'title': 'Der Algorithmus'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 30,
#   'item_id': 30,
#   'new_data': {'author': 'Ben Fischer',
#                'id': 30,
#                'in_stock': 58,
#                'pages': 310,
#                'price': 23.9,
#                'publication_year': 2023,
#                'publisher': 'KrimiKunst',
#                'title': 'Mitternachtskrimi'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:02:08.339331Z'},
#  {'id': 31,
#   'item_id': 1,
#   'new_data': {'author': 'Max König',
#                'id': 1,
#                'pages': 320,
#                'price': 14.99,
#                'publication_year': 2020,
#                'publisher': 'DatenWelt Verlag',
#                'title': 'Die Algorithmische Reise'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 32,
#   'item_id': 2,
#   'new_data': {'author': 'Sarah Meißner',
#                'id': 2,
#                'pages': 280,
#                'price': 12.5,
#                'publication_year': 2021,
#                'publisher': 'CodeWerk',
#                'title': 'Python für Visionäre'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 33,
#   'item_id': 3,
#   'new_data': {'author': 'Dr. Jonas Berg',
#                'id': 3,
#                'pages': 340,
#                'price': 16.99,
#                'publication_year': 2023,
#                'publisher': 'Digitaler Puls',
#                'title': 'Künstliche Intelligenz verstehen'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 34,
#   'item_id': 4,
#   'new_data': {'author': 'Laura Stein',
#                'id': 4,
#                'pages': 265,
#                'price': 13.49,
#                'publication_year': 2022,
#                'publisher': 'TechnikKultur',
#                'title': 'Maschinenethik und Moral'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 35,
#   'item_id': 5,
#   'new_data': {'author': 'Kevin Trapp',
#                'id': 5,
#                'pages': 310,
#                'price': 11.0,
#                'publication_year': 2019,
#                'publisher': 'Datenkraft',
#                'title': 'SQL Meisterkurs'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 36,
#   'item_id': 6,
#   'new_data': {'author': 'Michael Krause',
#                'id': 6,
#                'pages': 295,
#                'price': 15.75,
#                'publication_year': 2022,
#                'publisher': 'CodeSchmiede',
#                'title': 'Effizient programmieren mit Rust'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 37,
#   'item_id': 7,
#   'new_data': {'author': 'Anne Roth',
#                'id': 7,
#                'pages': 270,
#                'price': 13.8,
#                'publication_year': 2021,
#                'publisher': 'WebArt',
#                'title': 'Frontend Entwicklung mit Stil'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 38,
#   'item_id': 8,
#   'new_data': {'author': 'Felix Hahn',
#                'id': 8,
#                'pages': 250,
#                'price': 10.9,
#                'publication_year': 2020,
#                'publisher': 'DB Pro Verlag',
#                'title': 'Datenbanken leicht gemacht'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 39,
#   'item_id': 9,
#   'new_data': {'author': 'Dr. Nina Vogt',
#                'id': 9,
#                'pages': 360,
#                'price': 17.49,
#                'publication_year': 2023,
#                'publisher': 'SozialDigital',
#                'title': 'Digitale Gesellschaft 4.0'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 40,
#   'item_id': 10,
#   'new_data': {'author': 'Thomas Ulrich',
#                'id': 10,
#                'pages': 330,
#                'price': 14.2,
#                'publication_year': 2021,
#                'publisher': 'DeepLearn Press',
#                'title': 'Reise durch das neuronale Netz'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 41,
#   'item_id': 11,
#   'new_data': {'author': 'Verena Schäfer',
#                'id': 11,
#                'pages': 280,
#                'price': 13.0,
#                'publication_year': 2022,
#                'publisher': 'SmartLife Verlag',
#                'title': 'KI im Alltag'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 42,
#   'item_id': 12,
#   'new_data': {'author': 'Oliver Kühn',
#                'id': 12,
#                'pages': 310,
#                'price': 12.6,
#                'publication_year': 2019,
#                'publisher': 'Formelwerk',
#                'title': 'Mathematik für Entwickler'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 43,
#   'item_id': 13,
#   'new_data': {'author': 'Christian Graf',
#                'id': 13,
#                'pages': 260,
#                'price': 11.7,
#                'publication_year': 2020,
#                'publisher': 'Wolkenwerk',
#                'title': 'Cloud Computing Basics'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 44,
#   'item_id': 14,
#   'new_data': {'author': 'Nicole Schmitt',
#                'id': 14,
#                'pages': 290,
#                'price': 15.0,
#                'publication_year': 2021,
#                'publisher': 'SystemDesign Verlag',
#                'title': 'Moderne Softwarearchitektur'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 45,
#   'item_id': 15,
#   'new_data': {'author': 'Andreas Kurz',
#                'id': 15,
#                'pages': 275,
#                'price': 14.1,
#                'publication_year': 2023,
#                'publisher': 'SicherDigital',
#                'title': 'Cybersicherheit verstehen'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 46,
#   'item_id': 16,
#   'new_data': {'author': 'Lena Maurer',
#                'id': 16,
#                'pages': 345,
#                'price': 17.9,
#                'publication_year': 2022,
#                'publisher': 'PraxisAI',
#                'title': 'Machine Learning in der Praxis'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 47,
#   'item_id': 17,
#   'new_data': {'author': 'Daniel Weiß',
#                'id': 17,
#                'pages': 220,
#                'price': 9.99,
#                'publication_year': 2021,
#                'publisher': 'CodingStart Verlag',
#                'title': 'Programmieren für Einsteiger'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 48,
#   'item_id': 18,
#   'new_data': {'author': 'Sophie Klein',
#                'id': 18,
#                'pages': 305,
#                'price': 13.4,
#                'publication_year': 2020,
#                'publisher': 'Insight Verlag',
#                'title': 'Data Science kompakt'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 49,
#   'item_id': 19,
#   'new_data': {'author': 'Marvin Schröder',
#                'id': 19,
#                'pages': 285,
#                'price': 12.99,
#                'publication_year': 2022,
#                'publisher': 'AppWorld Press',
#                'title': 'Entwicklung mobiler Apps'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 50,
#   'item_id': 20,
#   'new_data': {'author': 'Claudia Baum',
#                'id': 20,
#                'pages': 270,
#                'price': 11.6,
#                'publication_year': 2019,
#                'publisher': 'InfraVerlag',
#                'title': 'Netzwerke erklärt'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 51,
#   'item_id': 21,
#   'new_data': {'author': 'Julian Albrecht',
#                'id': 21,
#                'pages': 260,
#                'price': 12.5,
#                'publication_year': 2021,
#                'publisher': 'SkriptPlus',
#                'title': 'Automatisierung mit Python'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 52,
#   'item_id': 22,
#   'new_data': {'author': 'Leonie Marx',
#                'id': 22,
#                'pages': 240,
#                'price': 10.2,
#                'publication_year': 2020,
#                'publisher': 'CodeKunst',
#                'title': 'Kreatives Coden'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 53,
#   'item_id': 23,
#   'new_data': {'author': 'Tobias Engel',
#                'id': 23,
#                'pages': 275,
#                'price': 13.8,
#                'publication_year': 2022,
#                'publisher': 'WebDev Verlag',
#                'title': 'JavaScript intensiv'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 54,
#   'item_id': 24,
#   'new_data': {'author': 'Franziska Böhm',
#                'id': 24,
#                'pages': 300,
#                'price': 14.7,
#                'publication_year': 2021,
#                'publisher': 'DesignNow',
#                'title': 'Das UX Handbuch'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 55,
#   'item_id': 25,
#   'new_data': {'author': 'Paul Reinhardt',
#                'id': 25,
#                'pages': 265,
#                'price': 11.3,
#                'publication_year': 2019,
#                'publisher': 'Testdrive Verlag',
#                'title': 'Software testen professionell'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 56,
#   'item_id': 26,
#   'new_data': {'author': 'Karina Busch',
#                'id': 26,
#                'pages': 315,
#                'price': 16.2,
#                'publication_year': 2023,
#                'publisher': 'PixelForge',
#                'title': 'Game Development Einstieg'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 57,
#   'item_id': 27,
#   'new_data': {'author': 'Luca Breuer',
#                'id': 27,
#                'pages': 250,
#                'price': 10.8,
#                'publication_year': 2020,
#                'publisher': 'OpenMind Press',
#                'title': 'Open Source verstehen'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 58,
#   'item_id': 28,
#   'new_data': {'author': 'Heike Förster',
#                'id': 28,
#                'pages': 290,
#                'price': 13.99,
#                'publication_year': 2022,
#                'publisher': 'PlanIT Verlag',
#                'title': 'IT-Projektmanagement'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 59,
#   'item_id': 29,
#   'new_data': {'author': 'Niklas Ritter',
#                'id': 29,
#                'pages': 275,
#                'price': 12.2,
#                'publication_year': 2021,
#                'publisher': 'ChainBook',
#                'title': 'Blockchain Basics'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 60,
#   'item_id': 30,
#   'new_data': {'author': 'Katrin Scholz',
#                'id': 30,
#                'pages': 260,
#                'price': 11.95,
#                'publication_year': 2023,
#                'publisher': 'Teamflow Verlag',
#                'title': 'Agiles Arbeiten im Team'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'ebooks',
#   'timestamp': '2025-12-10T19:02:08.364688Z'},
#  {'id': 61,
#   'item_id': 1,
#   'new_data': {'id': 1,
#                'in_stock': 0,
#                'price': 14.99,
#                'publication_year': 2018,
#                'publisher': 'BluePeak Studios',
#                'title': 'The Silent Hour'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 62,
#   'item_id': 2,
#   'new_data': {'id': 2,
#                'in_stock': 0,
#                'price': 12.49,
#                'publication_year': 2020,
#                'publisher': 'Nightfall Pictures',
#                'title': 'Into the Shadows'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 63,
#   'item_id': 3,
#   'new_data': {'id': 3,
#                'in_stock': 53,
#                'price': 19.99,
#                'publication_year': 2022,
#                'publisher': 'Futura Films',
#                'title': 'Tomorrow’s Edge'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 64,
#   'item_id': 4,
#   'new_data': {'id': 4,
#                'in_stock': 45,
#                'price': 9.99,
#                'publication_year': 2017,
#                'publisher': 'Riverbend Media',
#                'title': 'Lost at Dawn'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 65,
#   'item_id': 5,
#   'new_data': {'id': 5,
#                'in_stock': 0,
#                'price': 16.75,
#                'publication_year': 2021,
#                'publisher': 'Lighthouse Entertainment',
#                'title': 'City of Dreams'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 66,
#   'item_id': 6,
#   'new_data': {'id': 6,
#                'in_stock': 36,
#                'price': 13.5,
#                'publication_year': 2019,
#                'publisher': 'Northern Reel',
#                'title': 'Beyond the Ice'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 67,
#   'item_id': 7,
#   'new_data': {'id': 7,
#                'in_stock': 12,
#                'price': 8.9,
#                'publication_year': 2016,
#                'publisher': 'Silvergate Films',
#                'title': 'Whispers in the Fog'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 68,
#   'item_id': 8,
#   'new_data': {'id': 8,
#                'in_stock': 8,
#                'price': 7.25,
#                'publication_year': 2015,
#                'publisher': 'Granite Motion',
#                'title': 'The Forgotten Trail'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 69,
#   'item_id': 9,
#   'new_data': {'id': 9,
#                'in_stock': 21,
#                'price': 11.99,
#                'publication_year': 2020,
#                'publisher': 'Vivid Motion',
#                'title': 'Parallel Lives'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 70,
#   'item_id': 10,
#   'new_data': {'id': 10,
#                'in_stock': 0,
#                'price': 10.45,
#                'publication_year': 2018,
#                'publisher': 'EchoFrame Studios',
#                'title': 'Fragments of Time'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 71,
#   'item_id': 11,
#   'new_data': {'id': 11,
#                'in_stock': 60,
#                'price': 21.0,
#                'publication_year': 2023,
#                'publisher': 'Phoenix Pictures',
#                'title': 'Red Horizon'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 72,
#   'item_id': 12,
#   'new_data': {'id': 12,
#                'in_stock': 19,
#                'price': 15.95,
#                'publication_year': 2022,
#                'publisher': 'Gridlock Films',
#                'title': 'The Last Equation'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 73,
#   'item_id': 13,
#   'new_data': {'id': 13,
#                'in_stock': 5,
#                'price': 12.0,
#                'publication_year': 2019,
#                'publisher': 'Pacific Vibe',
#                'title': 'Sunset Corridor'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 74,
#   'item_id': 14,
#   'new_data': {'id': 14,
#                'in_stock': 0,
#                'price': 6.8,
#                'publication_year': 2014,
#                'publisher': 'Cloudscape Media',
#                'title': 'The Distant Ring'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 75,
#   'item_id': 15,
#   'new_data': {'id': 15,
#                'in_stock': 41,
#                'price': 17.45,
#                'publication_year': 2021,
#                'publisher': 'OrbitLine Studios',
#                'title': 'Voices from Mars'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 76,
#   'item_id': 16,
#   'new_data': {'id': 16,
#                'in_stock': 18,
#                'price': 10.25,
#                'publication_year': 2017,
#                'publisher': 'WillowWorks',
#                'title': 'Golden Threads'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 77,
#   'item_id': 17,
#   'new_data': {'id': 17,
#                'in_stock': 10,
#                'price': 14.5,
#                'publication_year': 2020,
#                'publisher': 'Darkwell Studios',
#                'title': 'After the Storm'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 78,
#   'item_id': 18,
#   'new_data': {'id': 18,
#                'in_stock': 30,
#                'price': 9.95,
#                'publication_year': 2016,
#                'publisher': 'Timeless Films',
#                'title': 'The Clocks Unwind'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 79,
#   'item_id': 19,
#   'new_data': {'id': 19,
#                'in_stock': 1,
#                'price': 11.35,
#                'publication_year': 2018,
#                'publisher': 'Studio Magnolia',
#                'title': 'Velvet Skies'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 80,
#   'item_id': 20,
#   'new_data': {'id': 20,
#                'in_stock': 4,
#                'price': 12.9,
#                'publication_year': 2019,
#                'publisher': 'FrameShift Pictures',
#                'title': 'In the Pale Light'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 81,
#   'item_id': 21,
#   'new_data': {'id': 21,
#                'in_stock': 29,
#                'price': 15.0,
#                'publication_year': 2021,
#                'publisher': 'Cobalt Horizon',
#                'title': 'Exit Nowhere'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 82,
#   'item_id': 22,
#   'new_data': {'id': 22,
#                'in_stock': 38,
#                'price': 13.25,
#                'publication_year': 2022,
#                'publisher': 'Digital Rush',
#                'title': 'Code 94'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 83,
#   'item_id': 23,
#   'new_data': {'id': 23,
#                'in_stock': 23,
#                'price': 8.7,
#                'publication_year': 2015,
#                'publisher': 'Network Rewind',
#                'title': 'Final Broadcast'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 84,
#   'item_id': 24,
#   'new_data': {'id': 24,
#                'in_stock': 3,
#                'price': 14.99,
#                'publication_year': 2020,
#                'publisher': 'Moonbright Media',
#                'title': 'Through the Veil'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 85,
#   'item_id': 25,
#   'new_data': {'id': 25,
#                'in_stock': 50,
#                'price': 9.8,
#                'publication_year': 2017,
#                'publisher': 'MirrorLake Films',
#                'title': 'Hidden Reflections'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 86,
#   'item_id': 26,
#   'new_data': {'id': 26,
#                'in_stock': 31,
#                'price': 10.6,
#                'publication_year': 2019,
#                'publisher': 'UrbanCore Productions',
#                'title': 'Beneath the Metro'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 87,
#   'item_id': 27,
#   'new_data': {'id': 27,
#                'in_stock': 17,
#                'price': 19.5,
#                'publication_year': 2023,
#                'publisher': 'AltStream Cinema',
#                'title': 'Static Line'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 88,
#   'item_id': 28,
#   'new_data': {'id': 28,
#                'in_stock': 27,
#                'price': 12.75,
#                'publication_year': 2018,
#                'publisher': 'EmberEdge Films',
#                'title': 'Dust and Embers'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 89,
#   'item_id': 29,
#   'new_data': {'id': 29,
#                'in_stock': 11,
#                'price': 9.15,
#                'publication_year': 2016,
#                'publisher': 'Pulse Pictures',
#                'title': 'Nine Seconds'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 90,
#   'item_id': 30,
#   'new_data': {'id': 30,
#                'in_stock': 7,
#                'price': 16.2,
#                'publication_year': 2021,
#                'publisher': 'OpenTrack Studios',
#                'title': 'The Wander Loop'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'movies',
#   'timestamp': '2025-12-10T19:02:08.370985Z'},
#  {'id': 91,
#   'item_id': 31,
#   'new_data': {'author': 'Max Mustermann',
#                'id': 31,
#                'in_stock': 1,
#                'pages': 300,
#                'price': 19.99,
#                'publication_year': 2023,
#                'publisher': 'Test Verlag',
#                'title': 'Beispiel Buch'},
#   'old_data': None,
#   'operation': 'INSERT',
#   'table_name': 'books',
#   'timestamp': '2025-12-10T19:58:29.113429Z'}]
# c:\Users\Patrick\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# Mehrere Bücher erstellen
data_books =[
{
    "title": "2 Bücher auf einmal",
    "author": "Test Büchermann",
    "publication_year": 1977,
    "publisher": "Testbücher Verlag",
    "pages": 250,
    "price": 17.99,
    "in_stock": 3
},
{
    "title": "Beispiel Buch 2",
    "author": "Tex Mustermann",
    "publication_year": 1988,
    "publisher": "Test Test Verlag",
    "pages": 297,
    "price": 23.55,
    "in_stock": 25
}
]

# Da der Endpunkt auch eine Liste mit Büchern entgegen nimmt, sollte man auch mehrere Bücher hinzufügen können
# TBC
